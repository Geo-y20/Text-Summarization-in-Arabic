# %%
# !pip install transformers
# !pip install torch
# !pip install sentencepiece
# !pip install jsonlines
# Out:
# Requirement already satisfied: transformers in /usr/local/lib/python3.10/dist-packages (4.30.2)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from transformers) (3.12.2)
# Requirement already satisfied: huggingface-hub<1.0,>=0.14.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.16.3)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (1.22.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from transformers) (23.1)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (6.0)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (2022.10.31)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from transformers) (2.27.1)
# Requirement already satisfied: tokenizers!=0.11.3,<0.14,>=0.11.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.13.3)
# Requirement already satisfied: safetensors>=0.3.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.3.1)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.10/dist-packages (from transformers) (4.65.0)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.14.1->transformers) (2023.6.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.14.1->transformers) (4.6.3)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2023.5.7)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2.0.12)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (3.4)
# Requirement already satisfied: torch in /usr/local/lib/python3.10/dist-packages (2.0.1+cu118)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch) (3.12.2)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.10/dist-packages (from torch) (4.6.3)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch) (1.11.1)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch) (3.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch) (3.1.2)
# Requirement already satisfied: triton==2.0.0 in /usr/local/lib/python3.10/dist-packages (from torch) (2.0.0)
# Requirement already satisfied: cmake in /usr/local/lib/python3.10/dist-packages (from triton==2.0.0->torch) (3.25.2)
# Requirement already satisfied: lit in /usr/local/lib/python3.10/dist-packages (from triton==2.0.0->torch) (16.0.6)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch) (2.1.3)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch) (1.3.0)
# Requirement already satisfied: sentencepiece in /usr/local/lib/python3.10/dist-packages (0.1.99)
# Requirement already satisfied: jsonlines in /usr/local/lib/python3.10/dist-packages (3.1.0)
# Requirement already satisfied: attrs>=19.2.0 in /usr/local/lib/python3.10/dist-packages (from jsonlines) (23.1.0)

# %%
import json
from transformers import AutoTokenizer, AutoModelForSeq2SeqLM, AutoConfig
from torch.utils.data import Dataset, DataLoader
import jsonlines
import torch
from torch.utils.data import Dataset, DataLoader
#from transformers import AutoTokenizer, MBartForConditionalGeneration
from sklearn.model_selection import train_test_split

# Specify the device (CPU or GPU)
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# Load and preprocess the labeled dataset
def load_labeled_dataset(file_path):
    dataset = []
    with open(file_path, 'r', encoding='utf-8') as file:
        for line in file:
            data = json.loads(line)
            example_id = data['example_id']
            paragraph = data['paragraph']
            summary = data['summary']
            dataset.append((example_id, paragraph, summary))
    return dataset

# Custom dataset class
class LabeledDataset(Dataset):
    def __init__(self, data):
        self.data = data
        self.tokenizer = AutoTokenizer.from_pretrained('moussaKam/AraBART')


    def __len__(self):
        return len(self.data)

    def __getitem__(self, index):
        example_id, paragraph, summary = self.data[index]
        inputs = self.tokenizer.encode_plus(paragraph, truncation=True, padding='max_length', max_length=512,
                                            return_tensors='pt')
        labels = self.tokenizer.encode_plus(summary, truncation=True, padding='max_length', max_length=110,
                                            return_tensors='pt')
        return {
            'input_ids': inputs['input_ids'].squeeze(),
            'attention_mask': inputs['attention_mask'].squeeze(),
            'labels': labels['input_ids'].squeeze()
        }

# Load and preprocess the labeled dataset
labeled_dataset = load_labeled_dataset('/content/labeled_validation_dataset.jsonl')

# Create an instance of the labeled dataset
dataset = LabeledDataset(labeled_dataset)

# Configure the model
model_config = AutoConfig.from_pretrained('moussaKam/AraBART')
model_config.num_labels = 2  # Binary classification for sequence-to-sequence model

# Create the model
model = AutoModelForSeq2SeqLM.from_pretrained('moussaKam/AraBART', config=model_config)

# Move the model to the device
model.to(device)

# Define training parameters
batch_size = 8
num_epochs = 12
learning_rate = 1e-5

# Create a data loader for training
data_loader = DataLoader(dataset, batch_size=batch_size, shuffle=True)

# Define the optimizer and loss function
optimizer = torch.optim.AdamW(model.parameters(), lr=learning_rate)
criterion = torch.nn.CrossEntropyLoss()

# Training loop
for epoch in range(num_epochs):
    model.train()
    for batch in data_loader:
        optimizer.zero_grad()
        input_ids = batch['input_ids'].to(device)
        attention_mask = batch['attention_mask'].to(device)
        labels = batch['labels'].to(device)

        outputs = model(input_ids=input_ids, attention_mask=attention_mask, labels=labels)
        loss = outputs.loss
        logits = outputs.logits

        loss.backward()
        optimizer.step()

        # Print the loss or any other metrics

    # Evaluate the model on validation set after each epoch
    model.eval()
    # Run validation and calculate metrics

# Save the trained model
model.save_pretrained('trained_model')

# %%
import json
import numpy as np
from transformers import AutoTokenizer, AutoModelForSeq2SeqLM
import torch
from torch.utils.data import Dataset, DataLoader

# Load the trained model
model_path = '/content/trained_model'
model = AutoModelForSeq2SeqLM.from_pretrained(model_path)

# Specify the device (CPU or GPU)
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# Move the model to the device
model.to(device)

# Load the tokenizer
tokenizer = AutoTokenizer.from_pretrained('moussaKam/AraBART')

# Load the unlabeled validation dataset
def load_validation_dataset(file_path):
    dataset = []
    with open(file_path, 'r', encoding='utf-8') as file:
        for line in file:
            data = json.loads(line)
            example_id = data['example_id']
            paragraph = data['paragraph']
            dataset.append((example_id, paragraph))
    return dataset

# Custom dataset class for validation dataset
class ValidationDataset(Dataset):
    def __init__(self, data):
        self.data = data
        self.tokenizer = AutoTokenizer.from_pretrained('moussaKam/AraBART')

    def __len__(self):
        return len(self.data)

    def __getitem__(self, index):
        example_id, paragraph = self.data[index]
        inputs = self.tokenizer.encode_plus(paragraph, truncation=True, padding='max_length', max_length=512,
                                            return_tensors='pt')
        return {
            'example_id': example_id,
            'paragraph': paragraph,
            'input_ids': inputs['input_ids'].squeeze(),
            'attention_mask': inputs['attention_mask'].squeeze()
        }

# Load the unlabeled validation dataset
validation_dataset = load_validation_dataset('/content/validation_data.jsonl')

# Create an instance of the validation dataset
dataset = ValidationDataset(validation_dataset)

# Define batch size
batch_size = 8

# Create a data loader for validation dataset
data_loader = DataLoader(dataset, batch_size=batch_size, shuffle=False)

# Generate predictions
predictions = []
original_word_counts = []  # To store the word counts of original paragraphs
model.eval()
for batch in data_loader:
    example_ids = batch['example_id']
    input_ids = batch['input_ids'].to(device)
    attention_mask = batch['attention_mask'].to(device)

    for example_id, inp_id, att_mask, paragraph in zip(example_ids, input_ids, attention_mask, batch['paragraph']):
        paragraph_word_count = len(tokenizer.tokenize(paragraph))

        # Calculate the target length as a percentage of the paragraph's length
        target_length = int(0.47 * paragraph_word_count)  # Adjust the percentage as needed

        # Generate a new summary with the adjusted length
        outputs = model.generate(input_ids=inp_id.unsqueeze(0), attention_mask=att_mask.unsqueeze(0),
                                 max_length=target_length)

        summary = tokenizer.decode(outputs[0], skip_special_tokens=True)
        prediction = {'example_id': example_id.item(), 'summary': summary}
        predictions.append(prediction)
        original_word_counts.append(paragraph_word_count)

# Save the predictions to predictions.jsonl
with open('predictions.jsonl', 'w', encoding='utf-8') as file:
    for prediction in predictions:
        file.write(json.dumps(prediction, ensure_ascii=False) + '\n')

# Compute the Compression Ratio
target_ratio_lower = 0.3
target_ratio_upper = 0.4

compression_ratios = []
for prediction, word_count in zip(predictions, original_word_counts):
    summary = prediction['summary']
    summary_word_count = len(tokenizer.tokenize(summary))
    compression_ratio = summary_word_count / word_count
    compression_ratios.append(compression_ratio)

# Calculate the score based on the Compression Ratio
scores = []
for compression_ratio in compression_ratios:
    if target_ratio_lower <= compression_ratio <= target_ratio_upper:
        scores.append(1.0)
    else:
        score = max(0, (target_ratio_upper - compression_ratio) / (target_ratio_upper - target_ratio_lower))
        scores.append(score)

# Print the Compression Ratios and Scores
for i, prediction in enumerate(predictions):
    example_id = prediction['example_id']
    original_paragraph_length = original_word_counts[i]
    summary_length = len(tokenizer.tokenize(prediction['summary']))
    print("Example ID:", example_id)
    print("Original Paragraph Length:", original_paragraph_length)
    print("Summary Length:", summary_length)
    print("Compression Ratio:", compression_ratios[i])
    print("Score:", scores[i])
    print()

# Compute the average Compression Ratio
average_compression_ratio = np.mean(compression_ratios)
print("Average Compression Ratio:", average_compression_ratio)

# Compute the average score
average_score = np.mean(scores)
print("Average Score:", average_score)
# Out:
# Example ID: 0
# Original Paragraph Length: 460
# Summary Length: 204
# Compression Ratio: 0.4434782608695652
# Score: 0
#
# Example ID: 1
# Original Paragraph Length: 173
# Summary Length: 77
# Compression Ratio: 0.44508670520231214
# Score: 0
#
# Example ID: 2
# Original Paragraph Length: 125
# Summary Length: 52
# Compression Ratio: 0.416
# Score: 0
#
# Example ID: 3
# Original Paragraph Length: 268
# Summary Length: 86
# Compression Ratio: 0.3208955223880597
# Score: 1.0
#
# Example ID: 4
# Original Paragraph Length: 116
# Summary Length: 48
# Compression Ratio: 0.41379310344827586
# Score: 0
#
# Example ID: 5
# Original Paragraph Length: 249
# Summary Length: 108
# Compression Ratio: 0.43373493975903615
# Score: 0
#
# Example ID: 6
# Original Paragraph Length: 254
# Summary Length: 83
# Compression Ratio: 0.32677165354330706
# Score: 1.0
#
# Example ID: 7
# Original Paragraph Length: 298
# Summary Length: 132
# Compression Ratio: 0.4429530201342282
# Score: 0
#
# Example ID: 8
# Original Paragraph Length: 227
# Summary Length: 102
# Compression Ratio: 0.44933920704845814
# Score: 0
#
# Example ID: 9
# Original Paragraph Length: 386
# Summary Length: 173
# Compression Ratio: 0.4481865284974093
# Score: 0
#
# Example ID: 10
# Original Paragraph Length: 330
# Summary Length: 103
# Compression Ratio: 0.31212121212121213
# Score: 1.0
#
# Example ID: 11
# Original Paragraph Length: 254
# Summary Length: 86
# Compression Ratio: 0.33858267716535434
# Score: 1.0
#
# Example ID: 12
# Original Paragraph Length: 169
# Summary Length: 67
# Compression Ratio: 0.39644970414201186
# Score: 1.0
#
# Example ID: 13
# Original Paragraph Length: 73
# Summary Length: 30
# Compression Ratio: 0.410958904109589
# Score: 0
#
# Example ID: 14
# Original Paragraph Length: 273
# Summary Length: 95
# Compression Ratio: 0.34798534798534797
# Score: 1.0
#
# Example ID: 15
# Original Paragraph Length: 309
# Summary Length: 135
# Compression Ratio: 0.4368932038834951
# Score: 0
#
# Example ID: 16
# Original Paragraph Length: 160
# Summary Length: 53
# Compression Ratio: 0.33125
# Score: 1.0
#
# Example ID: 17
# Original Paragraph Length: 154
# Summary Length: 58
# Compression Ratio: 0.37662337662337664
# Score: 1.0
#
# Example ID: 18
# Original Paragraph Length: 194
# Summary Length: 85
# Compression Ratio: 0.4381443298969072
# Score: 0
#
# Example ID: 19
# Original Paragraph Length: 240
# Summary Length: 80
# Compression Ratio: 0.3333333333333333
# Score: 1.0
#
# Example ID: 20
# Original Paragraph Length: 158
# Summary Length: 67
# Compression Ratio: 0.4240506329113924
# Score: 0
#
# Example ID: 21
# Original Paragraph Length: 277
# Summary Length: 82
# Compression Ratio: 0.296028880866426
# Score: 1.03971119133574
#
# Example ID: 22
# Original Paragraph Length: 237
# Summary Length: 101
# Compression Ratio: 0.42616033755274263
# Score: 0
#
# Example ID: 23
# Original Paragraph Length: 137
# Summary Length: 52
# Compression Ratio: 0.3795620437956204
# Score: 1.0
#
# Example ID: 24
# Original Paragraph Length: 175
# Summary Length: 74
# Compression Ratio: 0.4228571428571429
# Score: 0
#
# Example ID: 25
# Original Paragraph Length: 169
# Summary Length: 62
# Compression Ratio: 0.3668639053254438
# Score: 1.0
#
# Example ID: 26
# Original Paragraph Length: 171
# Summary Length: 76
# Compression Ratio: 0.4444444444444444
# Score: 0
#
# Example ID: 27
# Original Paragraph Length: 372
# Summary Length: 162
# Compression Ratio: 0.43548387096774194
# Score: 0
#
# Example ID: 28
# Original Paragraph Length: 131
# Summary Length: 56
# Compression Ratio: 0.42748091603053434
# Score: 0
#
# Example ID: 29
# Original Paragraph Length: 223
# Summary Length: 38
# Compression Ratio: 0.17040358744394618
# Score: 2.2959641255605376
#
# Example ID: 30
# Original Paragraph Length: 342
# Summary Length: 87
# Compression Ratio: 0.2543859649122807
# Score: 1.4561403508771926
#
# Example ID: 31
# Original Paragraph Length: 363
# Summary Length: 95
# Compression Ratio: 0.26170798898071623
# Score: 1.3829201101928374
#
# Example ID: 32
# Original Paragraph Length: 279
# Summary Length: 93
# Compression Ratio: 0.3333333333333333
# Score: 1.0
#
# Example ID: 33
# Original Paragraph Length: 496
# Summary Length: 216
# Compression Ratio: 0.43548387096774194
# Score: 0
#
# Example ID: 34
# Original Paragraph Length: 286
# Summary Length: 126
# Compression Ratio: 0.4405594405594406
# Score: 0
#
# Example ID: 35
# Original Paragraph Length: 387
# Summary Length: 112
# Compression Ratio: 0.28940568475452194
# Score: 1.1059431524547805
#
# Example ID: 36
# Original Paragraph Length: 276
# Summary Length: 124
# Compression Ratio: 0.4492753623188406
# Score: 0
#
# Example ID: 37
# Original Paragraph Length: 274
# Summary Length: 122
# Compression Ratio: 0.44525547445255476
# Score: 0
#
# Example ID: 38
# Original Paragraph Length: 197
# Summary Length: 84
# Compression Ratio: 0.4263959390862944
# Score: 0
#
# Example ID: 39
# Original Paragraph Length: 377
# Summary Length: 102
# Compression Ratio: 0.27055702917771884
# Score: 1.2944297082228113
#
# Example ID: 40
# Original Paragraph Length: 441
# Summary Length: 93
# Compression Ratio: 0.2108843537414966
# Score: 1.8911564625850334
#
# Example ID: 41
# Original Paragraph Length: 260
# Summary Length: 92
# Compression Ratio: 0.35384615384615387
# Score: 1.0
#
# Example ID: 42
# Original Paragraph Length: 344
# Summary Length: 66
# Compression Ratio: 0.19186046511627908
# Score: 2.0813953488372086
#
# Example ID: 43
# Original Paragraph Length: 206
# Summary Length: 59
# Compression Ratio: 0.28640776699029125
# Score: 1.1359223300970873
#
# Example ID: 44
# Original Paragraph Length: 449
# Summary Length: 102
# Compression Ratio: 0.22717149220489977
# Score: 1.728285077951002
#
# Example ID: 45
# Original Paragraph Length: 377
# Summary Length: 97
# Compression Ratio: 0.2572944297082228
# Score: 1.4270557029177717
#
# Example ID: 46
# Original Paragraph Length: 661
# Summary Length: 42
# Compression Ratio: 0.06354009077155824
# Score: 3.3645990922844167
#
# Example ID: 47
# Original Paragraph Length: 404
# Summary Length: 61
# Compression Ratio: 0.15099009900990099
# Score: 2.4900990099009896
#
# Example ID: 48
# Original Paragraph Length: 335
# Summary Length: 76
# Compression Ratio: 0.22686567164179106
# Score: 1.731343283582089
#
# Example ID: 49
# Original Paragraph Length: 266
# Summary Length: 32
# Compression Ratio: 0.12030075187969924
# Score: 2.7969924812030067
#
# Example ID: 50
# Original Paragraph Length: 450
# Summary Length: 128
# Compression Ratio: 0.28444444444444444
# Score: 1.1555555555555554
#
# Example ID: 51
# Original Paragraph Length: 525
# Summary Length: 85
# Compression Ratio: 0.1619047619047619
# Score: 2.3809523809523805
#
# Example ID: 52
# Original Paragraph Length: 175
# Summary Length: 37
# Compression Ratio: 0.21142857142857144
# Score: 1.8857142857142852
#
# Example ID: 53
# Original Paragraph Length: 238
# Summary Length: 50
# Compression Ratio: 0.21008403361344538
# Score: 1.8991596638655457
#
# Example ID: 54
# Original Paragraph Length: 226
# Summary Length: 76
# Compression Ratio: 0.336283185840708
# Score: 1.0
#
# Example ID: 55
# Original Paragraph Length: 601
# Summary Length: 171
# Compression Ratio: 0.28452579034941766
# Score: 1.1547420965058233
#
# Example ID: 56
# Original Paragraph Length: 346
# Summary Length: 82
# Compression Ratio: 0.23699421965317918
# Score: 1.6300578034682078
#
# Example ID: 57
# Original Paragraph Length: 372
# Summary Length: 111
# Compression Ratio: 0.29838709677419356
# Score: 1.0161290322580643
#
# Example ID: 58
# Original Paragraph Length: 778
# Summary Length: 182
# Compression Ratio: 0.23393316195372751
# Score: 1.6606683804627245
#
# Example ID: 59
# Original Paragraph Length: 270
# Summary Length: 48
# Compression Ratio: 0.17777777777777778
# Score: 2.2222222222222214
#
# Example ID: 60
# Original Paragraph Length: 542
# Summary Length: 144
# Compression Ratio: 0.2656826568265683
# Score: 1.343173431734317
#
# Example ID: 61
# Original Paragraph Length: 207
# Summary Length: 49
# Compression Ratio: 0.23671497584541062
# Score: 1.6328502415458934
#
# Example ID: 62
# Original Paragraph Length: 400
# Summary Length: 144
# Compression Ratio: 0.36
# Score: 1.0
#
# Example ID: 63
# Original Paragraph Length: 240
# Summary Length: 68
# Compression Ratio: 0.2833333333333333
# Score: 1.1666666666666665
#
# Example ID: 64
# Original Paragraph Length: 367
# Summary Length: 129
# Compression Ratio: 0.35149863760217986
# Score: 1.0
#
# Example ID: 65
# Original Paragraph Length: 268
# Summary Length: 52
# Compression Ratio: 0.19402985074626866
# Score: 2.0597014925373127
#
# Example ID: 66
# Original Paragraph Length: 267
# Summary Length: 84
# Compression Ratio: 0.3146067415730337
# Score: 1.0
#
# Example ID: 67
# Original Paragraph Length: 519
# Summary Length: 189
# Compression Ratio: 0.36416184971098264
# Score: 1.0
#
# Example ID: 68
# Original Paragraph Length: 172
# Summary Length: 51
# Compression Ratio: 0.29651162790697677
# Score: 1.0348837209302322
#
# Example ID: 69
# Original Paragraph Length: 220
# Summary Length: 55
# Compression Ratio: 0.25
# Score: 1.4999999999999998
#
# Example ID: 70
# Original Paragraph Length: 395
# Summary Length: 89
# Compression Ratio: 0.22531645569620254
# Score: 1.7468354430379742
#
# Example ID: 71
# Original Paragraph Length: 301
# Summary Length: 125
# Compression Ratio: 0.4152823920265781
# Score: 0
#
# Example ID: 72
# Original Paragraph Length: 402
# Summary Length: 108
# Compression Ratio: 0.26865671641791045
# Score: 1.3134328358208953
#
# Example ID: 73
# Original Paragraph Length: 188
# Summary Length: 55
# Compression Ratio: 0.2925531914893617
# Score: 1.0744680851063828
#
# Example ID: 74
# Original Paragraph Length: 289
# Summary Length: 80
# Compression Ratio: 0.2768166089965398
# Score: 1.2318339100346016
#
# Example ID: 75
# Original Paragraph Length: 348
# Summary Length: 85
# Compression Ratio: 0.2442528735632184
# Score: 1.5574712643678157
#
# Example ID: 76
# Original Paragraph Length: 221
# Summary Length: 64
# Compression Ratio: 0.2895927601809955
# Score: 1.1040723981900449
#
# Example ID: 77
# Original Paragraph Length: 297
# Summary Length: 109
# Compression Ratio: 0.367003367003367
# Score: 1.0
#
# Example ID: 78
# Original Paragraph Length: 162
# Summary Length: 69
# Compression Ratio: 0.42592592592592593
# Score: 0
#
# Example ID: 79
# Original Paragraph Length: 193
# Summary Length: 83
# Compression Ratio: 0.43005181347150256
# Score: 0
#
# Example ID: 80
# Original Paragraph Length: 445
# Summary Length: 200
# Compression Ratio: 0.449438202247191
# Score: 0
#
# Example ID: 81
# Original Paragraph Length: 357
# Summary Length: 158
# Compression Ratio: 0.4425770308123249
# Score: 0
#
# Example ID: 82
# Original Paragraph Length: 263
# Summary Length: 100
# Compression Ratio: 0.38022813688212925
# Score: 1.0
#
# Example ID: 83
# Original Paragraph Length: 474
# Summary Length: 213
# Compression Ratio: 0.44936708860759494
# Score: 0
#
# Example ID: 84
# Original Paragraph Length: 169
# Summary Length: 75
# Compression Ratio: 0.4437869822485207
# Score: 0
#
# Example ID: 85
# Original Paragraph Length: 270
# Summary Length: 110
# Compression Ratio: 0.4074074074074074
# Score: 0
#
# Example ID: 86
# Original Paragraph Length: 166
# Summary Length: 74
# Compression Ratio: 0.4457831325301205
# Score: 0
#
# Example ID: 87
# Original Paragraph Length: 389
# Summary Length: 105
# Compression Ratio: 0.2699228791773779
# Score: 1.3007712082262208
#
# Example ID: 88
# Original Paragraph Length: 227
# Summary Length: 102
# Compression Ratio: 0.44933920704845814
# Score: 0
#
# Example ID: 89
# Original Paragraph Length: 233
# Summary Length: 104
# Compression Ratio: 0.44635193133047213
# Score: 0
#
# Example ID: 90
# Original Paragraph Length: 353
# Summary Length: 160
# Compression Ratio: 0.45325779036827196
# Score: 0
#
# Example ID: 91
# Original Paragraph Length: 179
# Summary Length: 77
# Compression Ratio: 0.4301675977653631
# Score: 0
#
# Example ID: 92
# Original Paragraph Length: 293
# Summary Length: 133
# Compression Ratio: 0.4539249146757679
# Score: 0
#
# Example ID: 93
# Original Paragraph Length: 247
# Summary Length: 100
# Compression Ratio: 0.4048582995951417
# Score: 0
#
# Example ID: 94
# Original Paragraph Length: 214
# Summary Length: 76
# Compression Ratio: 0.35514018691588783
# Score: 1.0
#
# Example ID: 95
# Original Paragraph Length: 374
# Summary Length: 166
# Compression Ratio: 0.44385026737967914
# Score: 0
#
# Example ID: 96
# Original Paragraph Length: 144
# Summary Length: 63
# Compression Ratio: 0.4375
# Score: 0
#
# Example ID: 97
# Original Paragraph Length: 101
# Summary Length: 41
# Compression Ratio: 0.40594059405940597
# Score: 0
#
# Example ID: 98
# Original Paragraph Length: 287
# Summary Length: 129
# Compression Ratio: 0.44947735191637633
# Score: 0
#
# Example ID: 99
# Original Paragraph Length: 207
# Summary Length: 92
# Compression Ratio: 0.4444444444444444
# Score: 0
#
# Example ID: 100
# Original Paragraph Length: 205
# Summary Length: 76
# Compression Ratio: 0.37073170731707317
# Score: 1.0
#
# Example ID: 101
# Original Paragraph Length: 94
# Summary Length: 40
# Compression Ratio: 0.425531914893617
# Score: 0
#
# Example ID: 102
# Original Paragraph Length: 294
# Summary Length: 127
# Compression Ratio: 0.43197278911564624
# Score: 0
#
# Example ID: 103
# Original Paragraph Length: 195
# Summary Length: 82
# Compression Ratio: 0.4205128205128205
# Score: 0
#
# Example ID: 104
# Original Paragraph Length: 348
# Summary Length: 114
# Compression Ratio: 0.3275862068965517
# Score: 1.0
#
# Example ID: 105
# Original Paragraph Length: 244
# Summary Length: 107
# Compression Ratio: 0.4385245901639344
# Score: 0
#
# Example ID: 106
# Original Paragraph Length: 147
# Summary Length: 62
# Compression Ratio: 0.4217687074829932
# Score: 0
#
# Example ID: 107
# Original Paragraph Length: 266
# Summary Length: 95
# Compression Ratio: 0.35714285714285715
# Score: 1.0
#
# Example ID: 108
# Original Paragraph Length: 180
# Summary Length: 79
# Compression Ratio: 0.4388888888888889
# Score: 0
#
# Example ID: 109
# Original Paragraph Length: 202
# Summary Length: 86
# Compression Ratio: 0.42574257425742573
# Score: 0
#
# Example ID: 110
# Original Paragraph Length: 333
# Summary Length: 104
# Compression Ratio: 0.3123123123123123
# Score: 1.0
#
# Example ID: 111
# Original Paragraph Length: 590
# Summary Length: 264
# Compression Ratio: 0.44745762711864406
# Score: 0
#
# Example ID: 112
# Original Paragraph Length: 225
# Summary Length: 95
# Compression Ratio: 0.4222222222222222
# Score: 0
#
# Example ID: 113
# Original Paragraph Length: 243
# Summary Length: 83
# Compression Ratio: 0.34156378600823045
# Score: 1.0
#
# Example ID: 114
# Original Paragraph Length: 240
# Summary Length: 98
# Compression Ratio: 0.4083333333333333
# Score: 0
#
# Example ID: 115
# Original Paragraph Length: 312
# Summary Length: 141
# Compression Ratio: 0.4519230769230769
# Score: 0
#
# Example ID: 116
# Original Paragraph Length: 148
# Summary Length: 62
# Compression Ratio: 0.4189189189189189
# Score: 0
#
# Example ID: 117
# Original Paragraph Length: 144
# Summary Length: 59
# Compression Ratio: 0.4097222222222222
# Score: 0
#
# Example ID: 118
# Original Paragraph Length: 320
# Summary Length: 135
# Compression Ratio: 0.421875
# Score: 0
#
# Example ID: 119
# Original Paragraph Length: 215
# Summary Length: 87
# Compression Ratio: 0.4046511627906977
# Score: 0
#
# Example ID: 120
# Original Paragraph Length: 252
# Summary Length: 114
# Compression Ratio: 0.4523809523809524
# Score: 0
#
# Example ID: 121
# Original Paragraph Length: 81
# Summary Length: 33
# Compression Ratio: 0.4074074074074074
# Score: 0
#
# Example ID: 122
# Original Paragraph Length: 150
# Summary Length: 66
# Compression Ratio: 0.44
# Score: 0
#
# Example ID: 123
# Original Paragraph Length: 222
# Summary Length: 100
# Compression Ratio: 0.45045045045045046
# Score: 0
#
# Example ID: 124
# Original Paragraph Length: 182
# Summary Length: 76
# Compression Ratio: 0.4175824175824176
# Score: 0
#
# Example ID: 125
# Original Paragraph Length: 67
# Summary Length: 28
# Compression Ratio: 0.417910447761194
# Score: 0
#
# Example ID: 126
# Original Paragraph Length: 180
# Summary Length: 78
# Compression Ratio: 0.43333333333333335
# Score: 0
#
# Example ID: 127
# Original Paragraph Length: 246
# Summary Length: 86
# Compression Ratio: 0.34959349593495936
# Score: 1.0
#
# Example ID: 128
# Original Paragraph Length: 162
# Summary Length: 53
# Compression Ratio: 0.3271604938271605
# Score: 1.0
#
# Example ID: 129
# Original Paragraph Length: 420
# Summary Length: 190
# Compression Ratio: 0.4523809523809524
# Score: 0
#
# Example ID: 130
# Original Paragraph Length: 143
# Summary Length: 63
# Compression Ratio: 0.4405594405594406
# Score: 0
#
# Example ID: 131
# Original Paragraph Length: 181
# Summary Length: 81
# Compression Ratio: 0.44751381215469616
# Score: 0
#
# Example ID: 132
# Original Paragraph Length: 234
# Summary Length: 96
# Compression Ratio: 0.41025641025641024
# Score: 0
#
# Example ID: 133
# Original Paragraph Length: 175
# Summary Length: 64
# Compression Ratio: 0.3657142857142857
# Score: 1.0
#
# Example ID: 134
# Original Paragraph Length: 336
# Summary Length: 150
# Compression Ratio: 0.44642857142857145
# Score: 0
#
# Example ID: 135
# Original Paragraph Length: 187
# Summary Length: 79
# Compression Ratio: 0.42245989304812837
# Score: 0
#
# Example ID: 136
# Original Paragraph Length: 280
# Summary Length: 125
# Compression Ratio: 0.44642857142857145
# Score: 0
#
# Example ID: 137
# Original Paragraph Length: 202
# Summary Length: 88
# Compression Ratio: 0.43564356435643564
# Score: 0
#
# Example ID: 138
# Original Paragraph Length: 151
# Summary Length: 66
# Compression Ratio: 0.4370860927152318
# Score: 0
#
# Example ID: 139
# Original Paragraph Length: 54
# Summary Length: 22
# Compression Ratio: 0.4074074074074074
# Score: 0
#
# Example ID: 140
# Original Paragraph Length: 80
# Summary Length: 34
# Compression Ratio: 0.425
# Score: 0
#
# Example ID: 141
# Original Paragraph Length: 109
# Summary Length: 44
# Compression Ratio: 0.4036697247706422
# Score: 0
#
# Example ID: 142
# Original Paragraph Length: 185
# Summary Length: 78
# Compression Ratio: 0.42162162162162165
# Score: 0
#
# Example ID: 143
# Original Paragraph Length: 162
# Summary Length: 62
# Compression Ratio: 0.38271604938271603
# Score: 1.0
#
# Example ID: 144
# Original Paragraph Length: 166
# Summary Length: 65
# Compression Ratio: 0.39156626506024095
# Score: 1.0
#
# Example ID: 145
# Original Paragraph Length: 154
# Summary Length: 65
# Compression Ratio: 0.42207792207792205
# Score: 0
#
# Example ID: 146
# Original Paragraph Length: 275
# Summary Length: 68
# Compression Ratio: 0.24727272727272728
# Score: 1.527272727272727
#
# Example ID: 147
# Original Paragraph Length: 155
# Summary Length: 67
# Compression Ratio: 0.432258064516129
# Score: 0
#
# Example ID: 148
# Original Paragraph Length: 424
# Summary Length: 101
# Compression Ratio: 0.23820754716981132
# Score: 1.6179245283018864
#
# Example ID: 149
# Original Paragraph Length: 176
# Summary Length: 67
# Compression Ratio: 0.3806818181818182
# Score: 1.0
#
# Example ID: 150
# Original Paragraph Length: 283
# Summary Length: 109
# Compression Ratio: 0.38515901060070673
# Score: 1.0
#
# Example ID: 151
# Original Paragraph Length: 99
# Summary Length: 43
# Compression Ratio: 0.43434343434343436
# Score: 0
#
# Example ID: 152
# Original Paragraph Length: 188
# Summary Length: 84
# Compression Ratio: 0.44680851063829785
# Score: 0
#
# Example ID: 153
# Original Paragraph Length: 200
# Summary Length: 42
# Compression Ratio: 0.21
# Score: 1.8999999999999997
#
# Example ID: 154
# Original Paragraph Length: 208
# Summary Length: 72
# Compression Ratio: 0.34615384615384615
# Score: 1.0
#
# Example ID: 155
# Original Paragraph Length: 235
# Summary Length: 102
# Compression Ratio: 0.4340425531914894
# Score: 0
#
# Example ID: 156
# Original Paragraph Length: 86
# Summary Length: 36
# Compression Ratio: 0.4186046511627907
# Score: 0
#
# Example ID: 157
# Original Paragraph Length: 246
# Summary Length: 94
# Compression Ratio: 0.3821138211382114
# Score: 1.0
#
# Example ID: 158
# Original Paragraph Length: 260
# Summary Length: 68
# Compression Ratio: 0.26153846153846155
# Score: 1.3846153846153841
#
# Example ID: 159
# Original Paragraph Length: 276
# Summary Length: 89
# Compression Ratio: 0.322463768115942
# Score: 1.0
#
# Example ID: 160
# Original Paragraph Length: 300
# Summary Length: 51
# Compression Ratio: 0.17
# Score: 2.2999999999999994
#
# Example ID: 161
# Original Paragraph Length: 235
# Summary Length: 64
# Compression Ratio: 0.2723404255319149
# Score: 1.276595744680851
#
# Example ID: 162
# Original Paragraph Length: 375
# Summary Length: 130
# Compression Ratio: 0.3466666666666667
# Score: 1.0
#
# Example ID: 163
# Original Paragraph Length: 314
# Summary Length: 60
# Compression Ratio: 0.1910828025477707
# Score: 2.0891719745222925
#
# Example ID: 164
# Original Paragraph Length: 319
# Summary Length: 114
# Compression Ratio: 0.3573667711598746
# Score: 1.0
#
# Example ID: 165
# Original Paragraph Length: 239
# Summary Length: 69
# Compression Ratio: 0.28870292887029286
# Score: 1.1129707112970713
#
# Example ID: 166
# Original Paragraph Length: 272
# Summary Length: 49
# Compression Ratio: 0.1801470588235294
# Score: 2.198529411764705
#
# Example ID: 167
# Original Paragraph Length: 403
# Summary Length: 91
# Compression Ratio: 0.22580645161290322
# Score: 1.7419354838709675
#
# Example ID: 168
# Original Paragraph Length: 360
# Summary Length: 85
# Compression Ratio: 0.2361111111111111
# Score: 1.6388888888888886
#
# Example ID: 169
# Original Paragraph Length: 501
# Summary Length: 151
# Compression Ratio: 0.3013972055888224
# Score: 1.0
#
# Example ID: 170
# Original Paragraph Length: 487
# Summary Length: 89
# Compression Ratio: 0.18275154004106775
# Score: 2.172484599589322
#
# Example ID: 171
# Original Paragraph Length: 325
# Summary Length: 92
# Compression Ratio: 0.28307692307692306
# Score: 1.1692307692307693
#
# Example ID: 172
# Original Paragraph Length: 298
# Summary Length: 85
# Compression Ratio: 0.28523489932885904
# Score: 1.1476510067114094
#
# Example ID: 173
# Original Paragraph Length: 190
# Summary Length: 74
# Compression Ratio: 0.3894736842105263
# Score: 1.0
#
# Example ID: 174
# Original Paragraph Length: 260
# Summary Length: 79
# Compression Ratio: 0.3038461538461538
# Score: 1.0
#
# Example ID: 175
# Original Paragraph Length: 235
# Summary Length: 51
# Compression Ratio: 0.2170212765957447
# Score: 1.8297872340425527
#
# Example ID: 176
# Original Paragraph Length: 459
# Summary Length: 110
# Compression Ratio: 0.23965141612200436
# Score: 1.6034858387799562
#
# Example ID: 177
# Original Paragraph Length: 203
# Summary Length: 68
# Compression Ratio: 0.33497536945812806
# Score: 1.0
#
# Example ID: 178
# Original Paragraph Length: 302
# Summary Length: 91
# Compression Ratio: 0.30132450331125826
# Score: 1.0
#
# Example ID: 179
# Original Paragraph Length: 495
# Summary Length: 87
# Compression Ratio: 0.17575757575757575
# Score: 2.2424242424242418
#
# Example ID: 180
# Original Paragraph Length: 216
# Summary Length: 78
# Compression Ratio: 0.3611111111111111
# Score: 1.0
#
# Example ID: 181
# Original Paragraph Length: 239
# Summary Length: 60
# Compression Ratio: 0.2510460251046025
# Score: 1.4895397489539748
#
# Example ID: 182
# Original Paragraph Length: 330
# Summary Length: 94
# Compression Ratio: 0.28484848484848485
# Score: 1.1515151515151514
#
# Example ID: 183
# Original Paragraph Length: 281
# Summary Length: 86
# Compression Ratio: 0.30604982206405695
# Score: 1.0
#
# Example ID: 184
# Original Paragraph Length: 436
# Summary Length: 63
# Compression Ratio: 0.1444954128440367
# Score: 2.5550458715596327
#
# Example ID: 185
# Original Paragraph Length: 306
# Summary Length: 131
# Compression Ratio: 0.42810457516339867
# Score: 0
#
# Example ID: 186
# Original Paragraph Length: 317
# Summary Length: 111
# Compression Ratio: 0.3501577287066246
# Score: 1.0
#
# Example ID: 187
# Original Paragraph Length: 371
# Summary Length: 169
# Compression Ratio: 0.4555256064690027
# Score: 0
#
# Example ID: 188
# Original Paragraph Length: 431
# Summary Length: 197
# Compression Ratio: 0.45707656612529
# Score: 0
#
# Example ID: 189
# Original Paragraph Length: 347
# Summary Length: 118
# Compression Ratio: 0.3400576368876081
# Score: 1.0
#
# Example ID: 190
# Original Paragraph Length: 450
# Summary Length: 107
# Compression Ratio: 0.23777777777777778
# Score: 1.6222222222222218
#
# Example ID: 191
# Original Paragraph Length: 404
# Summary Length: 184
# Compression Ratio: 0.45544554455445546
# Score: 0
#
# Example ID: 192
# Original Paragraph Length: 444
# Summary Length: 203
# Compression Ratio: 0.4572072072072072
# Score: 0
#
# Example ID: 193
# Original Paragraph Length: 344
# Summary Length: 156
# Compression Ratio: 0.45348837209302323
# Score: 0
#
# Example ID: 194
# Original Paragraph Length: 323
# Summary Length: 147
# Compression Ratio: 0.4551083591331269
# Score: 0
#
# Example ID: 195
# Original Paragraph Length: 449
# Summary Length: 113
# Compression Ratio: 0.2516703786191537
# Score: 1.4832962138084627
#
# Example ID: 196
# Original Paragraph Length: 366
# Summary Length: 167
# Compression Ratio: 0.4562841530054645
# Score: 0
#
# Example ID: 197
# Original Paragraph Length: 290
# Summary Length: 96
# Compression Ratio: 0.3310344827586207
# Score: 1.0
#
# Example ID: 198
# Original Paragraph Length: 428
# Summary Length: 196
# Compression Ratio: 0.45794392523364486
# Score: 0
#
# Example ID: 199
# Original Paragraph Length: 435
# Summary Length: 151
# Compression Ratio: 0.3471264367816092
# Score: 1.0
#
# Example ID: 200
# Original Paragraph Length: 294
# Summary Length: 95
# Compression Ratio: 0.3231292517006803
# Score: 1.0
#
# Example ID: 201
# Original Paragraph Length: 344
# Summary Length: 111
# Compression Ratio: 0.3226744186046512
# Score: 1.0
#
# Example ID: 202
# Original Paragraph Length: 334
# Summary Length: 123
# Compression Ratio: 0.36826347305389223
# Score: 1.0
#
# Example ID: 203
# Original Paragraph Length: 398
# Summary Length: 112
# Compression Ratio: 0.2814070351758794
# Score: 1.1859296482412058
#
# Example ID: 204
# Original Paragraph Length: 321
# Summary Length: 109
# Compression Ratio: 0.3395638629283489
# Score: 1.0
#
# Example ID: 205
# Original Paragraph Length: 323
# Summary Length: 72
# Compression Ratio: 0.22291021671826625
# Score: 1.7708978328173373
#
# Example ID: 206
# Original Paragraph Length: 432
# Summary Length: 48
# Compression Ratio: 0.1111111111111111
# Score: 2.8888888888888884
#
# Example ID: 207
# Original Paragraph Length: 480
# Summary Length: 62
# Compression Ratio: 0.12916666666666668
# Score: 2.7083333333333326
#
# Example ID: 208
# Original Paragraph Length: 384
# Summary Length: 110
# Compression Ratio: 0.2864583333333333
# Score: 1.1354166666666667
#
# Example ID: 209
# Original Paragraph Length: 368
# Summary Length: 123
# Compression Ratio: 0.3342391304347826
# Score: 1.0
#
# Example ID: 210
# Original Paragraph Length: 407
# Summary Length: 125
# Compression Ratio: 0.3071253071253071
# Score: 1.0
#
# Example ID: 211
# Original Paragraph Length: 474
# Summary Length: 77
# Compression Ratio: 0.16244725738396623
# Score: 2.375527426160337
#
# Example ID: 212
# Original Paragraph Length: 321
# Summary Length: 81
# Compression Ratio: 0.2523364485981308
# Score: 1.4766355140186915
#
# Example ID: 213
# Original Paragraph Length: 341
# Summary Length: 155
# Compression Ratio: 0.45454545454545453
# Score: 0
#
# Example ID: 214
# Original Paragraph Length: 374
# Summary Length: 93
# Compression Ratio: 0.24866310160427807
# Score: 1.513368983957219
#
# Example ID: 215
# Original Paragraph Length: 455
# Summary Length: 132
# Compression Ratio: 0.29010989010989013
# Score: 1.0989010989010985
#
# Example ID: 216
# Original Paragraph Length: 465
# Summary Length: 213
# Compression Ratio: 0.45806451612903226
# Score: 0
#
# Example ID: 217
# Original Paragraph Length: 366
# Summary Length: 167
# Compression Ratio: 0.4562841530054645
# Score: 0
#
# Example ID: 218
# Original Paragraph Length: 382
# Summary Length: 80
# Compression Ratio: 0.2094240837696335
# Score: 1.9057591623036645
#
# Example ID: 219
# Original Paragraph Length: 383
# Summary Length: 114
# Compression Ratio: 0.29765013054830286
# Score: 1.0234986945169713
#
# Example ID: 220
# Original Paragraph Length: 347
# Summary Length: 98
# Compression Ratio: 0.2824207492795389
# Score: 1.1757925072046107
#
# Example ID: 221
# Original Paragraph Length: 471
# Summary Length: 216
# Compression Ratio: 0.4585987261146497
# Score: 0
#
# Example ID: 222
# Original Paragraph Length: 404
# Summary Length: 144
# Compression Ratio: 0.3564356435643564
# Score: 1.0
#
# Example ID: 223
# Original Paragraph Length: 469
# Summary Length: 215
# Compression Ratio: 0.4584221748400853
# Score: 0
#
# Example ID: 224
# Original Paragraph Length: 401
# Summary Length: 162
# Compression Ratio: 0.40399002493765584
# Score: 0
#
# Example ID: 225
# Original Paragraph Length: 435
# Summary Length: 125
# Compression Ratio: 0.28735632183908044
# Score: 1.1264367816091954
#
# Example ID: 226
# Original Paragraph Length: 428
# Summary Length: 97
# Compression Ratio: 0.2266355140186916
# Score: 1.7336448598130838
#
# Example ID: 227
# Original Paragraph Length: 495
# Summary Length: 227
# Compression Ratio: 0.4585858585858586
# Score: 0
#
# Example ID: 228
# Original Paragraph Length: 340
# Summary Length: 117
# Compression Ratio: 0.34411764705882353
# Score: 1.0
#
# Example ID: 229
# Original Paragraph Length: 400
# Summary Length: 183
# Compression Ratio: 0.4575
# Score: 0
#
# Example ID: 230
# Original Paragraph Length: 387
# Summary Length: 99
# Compression Ratio: 0.2558139534883721
# Score: 1.4418604651162787
#
# Example ID: 231
# Original Paragraph Length: 344
# Summary Length: 22
# Compression Ratio: 0.06395348837209303
# Score: 3.3604651162790686
#
# Example ID: 232
# Original Paragraph Length: 462
# Summary Length: 95
# Compression Ratio: 0.20562770562770563
# Score: 1.9437229437229433
#
# Example ID: 233
# Original Paragraph Length: 307
# Summary Length: 123
# Compression Ratio: 0.4006514657980456
# Score: 0
#
# Example ID: 234
# Original Paragraph Length: 382
# Summary Length: 129
# Compression Ratio: 0.337696335078534
# Score: 1.0
#
# Example ID: 235
# Original Paragraph Length: 462
# Summary Length: 69
# Compression Ratio: 0.14935064935064934
# Score: 2.506493506493506
#
# Example ID: 236
# Original Paragraph Length: 379
# Summary Length: 173
# Compression Ratio: 0.45646437994722955
# Score: 0
#
# Example ID: 237
# Original Paragraph Length: 354
# Summary Length: 161
# Compression Ratio: 0.4548022598870056
# Score: 0
#
# Example ID: 238
# Original Paragraph Length: 307
# Summary Length: 139
# Compression Ratio: 0.4527687296416938
# Score: 0
#
# Example ID: 239
# Original Paragraph Length: 339
# Summary Length: 117
# Compression Ratio: 0.34513274336283184
# Score: 1.0
#
# Example ID: 240
# Original Paragraph Length: 289
# Summary Length: 82
# Compression Ratio: 0.2837370242214533
# Score: 1.1626297577854667
#
# Example ID: 241
# Original Paragraph Length: 286
# Summary Length: 93
# Compression Ratio: 0.32517482517482516
# Score: 1.0
#
# Example ID: 242
# Original Paragraph Length: 352
# Summary Length: 111
# Compression Ratio: 0.3153409090909091
# Score: 1.0
#
# Example ID: 243
# Original Paragraph Length: 410
# Summary Length: 187
# Compression Ratio: 0.4560975609756098
# Score: 0
#
# Example ID: 244
# Original Paragraph Length: 341
# Summary Length: 151
# Compression Ratio: 0.44281524926686217
# Score: 0
#
# Example ID: 245
# Original Paragraph Length: 444
# Summary Length: 112
# Compression Ratio: 0.25225225225225223
# Score: 1.4774774774774775
#
# Example ID: 246
# Original Paragraph Length: 427
# Summary Length: 105
# Compression Ratio: 0.2459016393442623
# Score: 1.5409836065573768
#
# Example ID: 247
# Original Paragraph Length: 354
# Summary Length: 159
# Compression Ratio: 0.4491525423728814
# Score: 0
#
# Example ID: 248
# Original Paragraph Length: 438
# Summary Length: 200
# Compression Ratio: 0.45662100456621
# Score: 0
#
# Example ID: 249
# Original Paragraph Length: 323
# Summary Length: 86
# Compression Ratio: 0.26625386996904027
# Score: 1.337461300309597
#
# Example ID: 250
# Original Paragraph Length: 365
# Summary Length: 142
# Compression Ratio: 0.38904109589041097
# Score: 1.0
#
# Example ID: 251
# Original Paragraph Length: 445
# Summary Length: 108
# Compression Ratio: 0.24269662921348314
# Score: 1.5730337078651682
#
# Example ID: 252
# Original Paragraph Length: 408
# Summary Length: 186
# Compression Ratio: 0.45588235294117646
# Score: 0
#
# Example ID: 253
# Original Paragraph Length: 452
# Summary Length: 207
# Compression Ratio: 0.4579646017699115
# Score: 0
#
# Example ID: 254
# Original Paragraph Length: 390
# Summary Length: 177
# Compression Ratio: 0.45384615384615384
# Score: 0
#
# Example ID: 255
# Original Paragraph Length: 397
# Summary Length: 131
# Compression Ratio: 0.32997481108312343
# Score: 1.0
#
# Example ID: 256
# Original Paragraph Length: 436
# Summary Length: 136
# Compression Ratio: 0.3119266055045872
# Score: 1.0
#
# Example ID: 257
# Original Paragraph Length: 402
# Summary Length: 97
# Compression Ratio: 0.24129353233830847
# Score: 1.587064676616915
#
# Example ID: 258
# Original Paragraph Length: 325
# Summary Length: 88
# Compression Ratio: 0.27076923076923076
# Score: 1.2923076923076922
#
# Example ID: 259
# Original Paragraph Length: 435
# Summary Length: 151
# Compression Ratio: 0.3471264367816092
# Score: 1.0
#
# Example ID: 260
# Original Paragraph Length: 375
# Summary Length: 91
# Compression Ratio: 0.24266666666666667
# Score: 1.573333333333333
#
# Example ID: 261
# Original Paragraph Length: 434
# Summary Length: 198
# Compression Ratio: 0.45622119815668205
# Score: 0
#
# Example ID: 262
# Original Paragraph Length: 337
# Summary Length: 73
# Compression Ratio: 0.2166172106824926
# Score: 1.8338278931750736
#
# Example ID: 263
# Original Paragraph Length: 436
# Summary Length: 63
# Compression Ratio: 0.1444954128440367
# Score: 2.5550458715596327
#
# Example ID: 264
# Original Paragraph Length: 319
# Summary Length: 109
# Compression Ratio: 0.34169278996865204
# Score: 1.0
#
# Example ID: 265
# Original Paragraph Length: 338
# Summary Length: 118
# Compression Ratio: 0.34911242603550297
# Score: 1.0
#
# Example ID: 266
# Original Paragraph Length: 342
# Summary Length: 89
# Compression Ratio: 0.260233918128655
# Score: 1.3976608187134498
#
# Example ID: 267
# Original Paragraph Length: 317
# Summary Length: 144
# Compression Ratio: 0.45425867507886436
# Score: 0
#
# Example ID: 268
# Original Paragraph Length: 428
# Summary Length: 196
# Compression Ratio: 0.45794392523364486
# Score: 0
#
# Example ID: 269
# Original Paragraph Length: 438
# Summary Length: 86
# Compression Ratio: 0.1963470319634703
# Score: 2.0365296803652964
#
# Example ID: 270
# Original Paragraph Length: 283
# Summary Length: 82
# Compression Ratio: 0.28975265017667845
# Score: 1.1024734982332154
#
# Example ID: 271
# Original Paragraph Length: 456
# Summary Length: 209
# Compression Ratio: 0.4583333333333333
# Score: 0
#
# Average Compression Ratio: 0.34717306282347654
# Average Score: 0.7992254045794189
